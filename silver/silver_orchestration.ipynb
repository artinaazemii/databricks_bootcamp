# %%
# Silver orchestration notebook
# Runs all Silver layer transformations in correct order

# CRM Silver
# Silver orchestration notebook

# CRM
dbutils.notebook.run("./crm/silver_crm_cust_info", 0)
dbutils.notebook.run("./crm/silver_crm_prd_info", 0)
dbutils.notebook.run("./crm/silver_crm_sales_details", 0)

# ERP
dbutils.notebook.run("./erp/silver_erp_cust_az12", 0)
dbutils.notebook.run("./erp/silver_erp_loc_a101", 0)
dbutils.notebook.run("./erp/silver_erp_px_cat_g1v2", 0)
