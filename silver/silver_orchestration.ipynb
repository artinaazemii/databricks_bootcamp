# %%
# Silver orchestration notebook
# Runs all Silver layer transformations in correct order

# CRM Silver
dbutils.notebook.run(
    "/Users/artinafazemi@gmail.com/databricks_bootcamp/silver/crm/silver_crm_cust_info",
    0
)

dbutils.notebook.run(
    "/Users/artinafazemi@gmail.com/databricks_bootcamp/silver/crm/silver_crm_prd_info",
    0
)

dbutils.notebook.run(
    "/Users/artinafazemi@gmail.com/databricks_bootcamp/silver/crm/silver_crm_sales_details",
    0
)

# ERP Silver
dbutils.notebook.run(
    "/Users/artinafazemi@gmail.com/databricks_bootcamp/silver/erp/silver_erp_cust_az12",
    0
)

dbutils.notebook.run(
    "/Users/artinafazemi@gmail.com/databricks_bootcamp/silver/erp/silver_erp_loc_a101",
    0
)

dbutils.notebook.run(
    "/Users/artinafazemi@gmail.com/databricks_bootcamp/silver/erp/silver_erp_px_cat_g1v2",
    0
)
