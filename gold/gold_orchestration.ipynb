# %%
# Gold orchestration notebook
# Builds Gold layer (dimensions and facts)

dbutils.notebook.run(
    "/Users/artinafazemi@gmail.com/databricks_bootcamp/gold/dim_customers",
    0
)

dbutils.notebook.run(
    "/Users/artinafazemi@gmail.com/databricks_bootcamp/gold/dim_products",
    0
)

dbutils.notebook.run(
    "/Users/artinafazemi@gmail.com/databricks_bootcamp/gold/fact_sales",
    0
)
